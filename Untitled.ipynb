# %%
# Cell 1 — the assembled World Cup table (this is what you'll analyze)
from fifa.matches import wc_matches, check_match_counts, latest_year

matches = wc_matches()          # 604 rows: 1994–2026, stage-labeled, shootout-resolved winners
print(matches.shape, "| latest year:", latest_year(matches))
matches.head()
# Out:
# (604, 14) | latest year: 2026
#         date  year  stage      home_team            away_team  home_score  \
# 0 1994-06-17  1994  group        Germany              Bolivia           1
# 1 1994-06-17  1994  group          Spain          South Korea           2
# 2 1994-06-18  1994  group       Colombia              Romania           1
# 3 1994-06-18  1994  group          Italy  Republic of Ireland           0
# 4 1994-06-18  1994  group  United States          Switzerland           1
#
#    away_score   outcome               winner  decided_by_shootout  \
# 0           0  home_win              Germany                False
# 1           2      draw                 <NA>                False
# 2           3  away_win              Romania                False
# 3           1  away_win  Republic of Ireland                False
# 4           1      draw                 <NA>                False
#
#    is_host_match  neutral             city        country
# ...

# %%
type(matches)
# Out:
# pandas.DataFrame
